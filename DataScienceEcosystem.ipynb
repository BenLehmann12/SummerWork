# %% [markdown]
# <b>Exercise 2 </b>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:2-title.png)

# %% [markdown]
# <b>Exercise 3</b>

# %% [markdown]
# In this notebook, We are utilizing Data Science tools to find out more about the ecosystem

# %% [markdown]
# ![3-intro.png](attachment:3-intro.png)

# %% [markdown]
# <b> Exercise 4 </b>

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. Java

# %% [markdown]
# ![4-dslanguages.png](attachment:4-dslanguages.png)

# %% [markdown]
# <b>Exercise 5</b>

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. TensorFlow
# 2. NumPy
# 3. SciPy
# 4. Pandas
# 5. Matplotlib

# %% [markdown]
# ![5-dslibraries.png](attachment:5-dslibraries.png)

# %% [markdown]
# <b>Exercise 6 </b>

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | JupyterLab         |
# | Google Colab       |

# %% [markdown]
# ![6-dstools.png](attachment:6-dstools.png)

# %% [markdown]
# <b>Exercise 7</b>

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:7-introarithmetic.png)

# %% [markdown]
# <b>Exercise 8</b>

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:8-multiplyandaddintegers.png)

# %% [markdown]
# <b>Exercise 9</b>

# %%
#This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![exercise9-hourstominutes.png](attachment:exercise9-hourstominutes.png)

# %% [markdown]
# <b>Exercise 10 </b>

# %% [markdown]
# <b>Objectives:</b>
# List popular languages for Data Science
# - Python
# - SQL
# - R

# %% [markdown]
# ![exercise10-objectives.png](attachment:exercise10-objectives.png)

# %% [markdown]
# <b> Exercise 11 </b>

# %% [markdown]
# ## Author
# Ben Lehmann

# %% [markdown]
# ![exercise11-authordetails.png](attachment:exercise11-authordetails.png)
